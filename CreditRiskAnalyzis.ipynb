# %% [markdown]
# <a href="https://colab.research.google.com/github/aaraszewska/CreditRisk/blob/main/CreditRiskAnalyzis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# imoprt library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import scipy.stats

# %% [markdown]
# Loading data set

# %%
df = pd.read_csv('/content/credit_risk_dataset.csv')
df
# Out:
#        person_age  person_income  ... cb_person_default_on_file  cb_person_cred_hist_length
# 0              22          59000  ...                         Y                           3
# 1              21           9600  ...                         N                           2
# 2              25           9600  ...                         N                           3
# 3              23          65500  ...                         N                           2
# 4              24          54400  ...                         Y                           4
# ...           ...            ...  ...                       ...                         ...
# 32576          57          53000  ...                         N                          30
# 32577          54         120000  ...                         N                          19
# 32578          65          76000  ...                         N                          28
# ...

# %% [markdown]
# **Data Cleaning**
